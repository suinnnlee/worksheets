# %% [markdown]
# # Worksheet 24
#
# Name: Suin Lee
# UID: U68592929
#
# ### Topics
#
# - Tuning Neural Networks
#
# ## Tuning Neural Networks
#
# Nothing to do in this worksheet except follow along in lecture / use this code to better understand Neural Networks.

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from tensorflow import keras, math, random, stack
from tensorflow.keras import layers, initializers
from tensorflow.keras.activations import relu

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=200, centers=centers, cluster_std=1,
                                random_state=1)

colors = np.array([x for x in 'bgrcmyk'])

# CURVE
def generate_curve_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : m.cos(4*x[0]) - x[1] < -.5 or m.cos(4*x[0]) - x[1] > .5, t)))
    Y = np.array([1 if m.cos(4*x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y

# The model - modify this
model = keras.models.Sequential()
model.add(layers.Dense(3, input_dim=2, activation="sigmoid"))
model.add(layers.Dense(1, activation="sigmoid"))
model.compile(loss="binary_crossentropy")

X, Y = generate_curve_data(t)

# plot the data
plt.scatter(X[:,0],X[:,1],color=colors[Y].tolist(), s=100, alpha=.9)
plt.show()

history = model.fit(X, Y, batch_size=50, epochs=200)

# Plot the decision boundary

# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
Z = model.predict(meshData)
Z = np.array([0 if x < .5 else 1 for x in Z])
Z = Z.reshape(xx.shape)
ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)
ax.axis('off')

# Plot also the training points
ax.scatter(X[:, 0], X[:, 1], color=colors[Y].tolist(), s=100, alpha=.9)
plt.title("Decision Boundary")
plt.show()
# Out:
# Epoch 1/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.8081
# Epoch 2/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.8031
# Epoch 3/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7996
# Epoch 4/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7966
# Epoch 5/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7939
# Epoch 6/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7914
# Epoch 7/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7890
# Epoch 8/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7868
# Epoch 9/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7846
# Epoch 10/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7824
# Epoch 11/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7802
# Epoch 12/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7782
# Epoch 13/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7761
# Epoch 14/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7741
# Epoch 15/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7722
# Epoch 16/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7703
# Epoch 17/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7683
# Epoch 18/200
# 3/3 [==============================] - 0s 907us/step - loss: 0.7663
# Epoch 19/200
# 3/3 [==============================] - 0s 993us/step - loss: 0.7643
# Epoch 20/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7624
# Epoch 21/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7605
# Epoch 22/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7587
# Epoch 23/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7568
# Epoch 24/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7550
# Epoch 25/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7532
# Epoch 26/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7514
# Epoch 27/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7495
# Epoch 28/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7477
# Epoch 29/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7459
# Epoch 30/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7441
# Epoch 31/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7424
# Epoch 32/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7407
# Epoch 33/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7390
# Epoch 34/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7374
# Epoch 35/200
# 3/3 [==============================] - 0s 987us/step - loss: 0.7356
# Epoch 36/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7340
# Epoch 37/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7323
# Epoch 38/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7307
# Epoch 39/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7290
# Epoch 40/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7274
# Epoch 41/200
# 3/3 [==============================] - 0s 918us/step - loss: 0.7257
# Epoch 42/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7241
# Epoch 43/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7225
# Epoch 44/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7209
# Epoch 45/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7193
# Epoch 46/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7178
# Epoch 47/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7161
# Epoch 48/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7146
# Epoch 49/200
# 3/3 [==============================] - 0s 924us/step - loss: 0.7129
# Epoch 50/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7114
# Epoch 51/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7100
# Epoch 52/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7085
# Epoch 53/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7070
# Epoch 54/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7056
# Epoch 55/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7042
# Epoch 56/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7027
# Epoch 57/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7013
# Epoch 58/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6999
# Epoch 59/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6984
# Epoch 60/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6970
# Epoch 61/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6956
# Epoch 62/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6941
# Epoch 63/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6928
# Epoch 64/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6914
# Epoch 65/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6901
# Epoch 66/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6887
# Epoch 67/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6873
# Epoch 68/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6860
# Epoch 69/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6846
# Epoch 70/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6833
# Epoch 71/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6820
# Epoch 72/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6806
# Epoch 73/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6793
# Epoch 74/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6779
# Epoch 75/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6765
# Epoch 76/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6752
# Epoch 77/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6739
# Epoch 78/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6726
# Epoch 79/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6714
# Epoch 80/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6701
# Epoch 81/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6688
# Epoch 82/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6674
# Epoch 83/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6661
# Epoch 84/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6648
# Epoch 85/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6634
# Epoch 86/200
# 3/3 [==============================] - 0s 924us/step - loss: 0.6621
# Epoch 87/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6609
# Epoch 88/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6597
# Epoch 89/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6584
# Epoch 90/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6572
# Epoch 91/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6559
# Epoch 92/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6547
# Epoch 93/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6535
# Epoch 94/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6523
# Epoch 95/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6512
# Epoch 96/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6501
# Epoch 97/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6488
# Epoch 98/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6478
# Epoch 99/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6466
# Epoch 100/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6455
# Epoch 101/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6444
# Epoch 102/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6433
# Epoch 103/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6422
# Epoch 104/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6411
# Epoch 105/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6400
# Epoch 106/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6390
# Epoch 107/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6379
# Epoch 108/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6368
# Epoch 109/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6357
# Epoch 110/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6347
# Epoch 111/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6336
# Epoch 112/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6325
# Epoch 113/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6315
# Epoch 114/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6305
# Epoch 115/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6294
# Epoch 116/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6284
# Epoch 117/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6274
# Epoch 118/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6263
# Epoch 119/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6254
# Epoch 120/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6245
# Epoch 121/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6235
# Epoch 122/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6225
# Epoch 123/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6215
# Epoch 124/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6206
# Epoch 125/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6196
# Epoch 126/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6187
# Epoch 127/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6178
# Epoch 128/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6168
# Epoch 129/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6158
# Epoch 130/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6149
# Epoch 131/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6139
# Epoch 132/200
# 3/3 [==============================] - 0s 999us/step - loss: 0.6129
# Epoch 133/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6120
# Epoch 134/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6110
# Epoch 135/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6101
# Epoch 136/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6092
# Epoch 137/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6082
# Epoch 138/200
# 3/3 [==============================] - 0s 939us/step - loss: 0.6073
# Epoch 139/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6064
# Epoch 140/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6056
# Epoch 141/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6048
# Epoch 142/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6037
# Epoch 143/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6030
# Epoch 144/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6021
# Epoch 145/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6013
# Epoch 146/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6004
# Epoch 147/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5996
# Epoch 148/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5987
# Epoch 149/200
# 3/3 [==============================] - 0s 982us/step - loss: 0.5980
# Epoch 150/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5971
# Epoch 151/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5962
# Epoch 152/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5954
# Epoch 153/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5946
# Epoch 154/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5937
# Epoch 155/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5928
# Epoch 156/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5919
# Epoch 157/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5911
# Epoch 158/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5902
# Epoch 159/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5894
# Epoch 160/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5887
# Epoch 161/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5878
# Epoch 162/200
# 3/3 [==============================] - 0s 989us/step - loss: 0.5871
# Epoch 163/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5862
# Epoch 164/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5855
# Epoch 165/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5847
# Epoch 166/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5840
# Epoch 167/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5832
# Epoch 168/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5824
# Epoch 169/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5816
# Epoch 170/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5809
# Epoch 171/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5801
# Epoch 172/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5795
# Epoch 173/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5787
# Epoch 174/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5779
# Epoch 175/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5771
# Epoch 176/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5763
# Epoch 177/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5756
# Epoch 178/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5749
# Epoch 179/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5741
# Epoch 180/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5734
# Epoch 181/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5726
# Epoch 182/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5719
# Epoch 183/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5712
# Epoch 184/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5705
# Epoch 185/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5697
# Epoch 186/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5690
# Epoch 187/200
# 3/3 [==============================] - 0s 999us/step - loss: 0.5682
# Epoch 188/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5676
# Epoch 189/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5667
# Epoch 190/200
# 3/3 [==============================] - 0s 979us/step - loss: 0.5660
# Epoch 191/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5653
# Epoch 192/200
# 3/3 [==============================] - 0s 942us/step - loss: 0.5646
# Epoch 193/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5638
# Epoch 194/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5631
# Epoch 195/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5624
# Epoch 196/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5617
# Epoch 197/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5610
# Epoch 198/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5603
# Epoch 199/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5596
# Epoch 200/200
# 3/3 [==============================] - 0s 931us/step - loss: 0.5589
# 3602/3602 [==============================] - 1s 400us/step
